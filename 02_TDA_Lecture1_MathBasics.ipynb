# %% [markdown]
# <a href="https://colab.research.google.com/github/apester/TDA/blob/main/02_TDA_Lecture1_MathBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 1 — Mathematical Basics

# %%
examples = [
("Interval",(1,0,0)),
("Circle",(1,1,0)),
("Two circles",(2,2,0)),
("Sphere",(1,0,1)),
("Torus",(1,2,1))
]

for name,b in examples:
    print(name,"-> β0=",b[0],"β1=",b[1],"β2=",b[2])
# Out:
# Interval -> β0= 1 β1= 0 β2= 0
# Circle -> β0= 1 β1= 1 β2= 0
# Two circles -> β0= 2 β1= 2 β2= 0
# Sphere -> β0= 1 β1= 0 β2= 1
# Torus -> β0= 1 β1= 2 β2= 1
